# %%
import matplotlib

x_coords = [1, 2, 3, 4]
y_coords = [2, 1, 4, 5]
# Out:
# Running cells with '.venv (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/workspaces/pyton_foundations/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
print("hello world ")
